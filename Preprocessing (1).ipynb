# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('breast-cancer.csv', sep=";")
dataset.head(10)
# Out:
#                   class    age menopause tumor-size inv-nodes node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2        no
# 5  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 6  no-recurrence-events  50-59   premeno      25-29       0-2        no
# 7  no-recurrence-events  60-69      ge40      20-24       0-2        no
# 8  no-recurrence-events  40-49   premeno      50-54       0-2        no
# 9  no-recurrence-events  40-49   premeno      20-24       0-2        no
#
#    deg-malig breast breast-quad irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# ...

# %% [markdown]
#   Variabel 'dataset' dipanggil dengan library 'pd'(pandas) untuk mengimport/membaca data dari sumber luar dengan function 'read_csv' untuk membaca sumber data file berupa csv
#   Lalu 'dataset.head(10)' digunakan untuk memanggil 10 data pertama pada sumber data

# %%
dataset.tail()
# Out:
#                  class    age menopause tumor-size inv-nodes node-caps  \
# 281  recurrence-events  30-39   premeno      30-34       0-2        no
# 282  recurrence-events  30-39   premeno      20-24       0-2        no
# 283  recurrence-events  60-69      ge40      20-24       0-2        no
# 284  recurrence-events  40-49      ge40      30-34    03-May        no
# 285  recurrence-events  50-59      ge40      30-34    03-May        no
#
#      deg-malig breast breast-quad irradiat
# 281          2   left     left_up       no
# 282          3   left     left_up      yes
# 283          1  right     left_up       no
# 284          3   left    left_low       no
# 285          3   left    left_low       no

# %% [markdown]
# 'dataset.tail()' digunakan untuk memanggil 5 data terakhir

# %%
dataset.dtypes
# Out:
# class          object
# age            object
# menopause      object
# tumor-size     object
# inv-nodes      object
# node-caps      object
# deg-malig       int64
# breast         object
# breast-quad    object
# irradiat       object
# dtype: object

# %% [markdown]
# 'dataset.dtypes' untuk mendeskripsikan atribut bertipe apa, apakah object, int ataupun string

# %%
dataset.describe().transpose()
# Out:
#            count      mean       std  min  25%  50%  75%  max
# deg-malig  286.0  2.048951  0.738217  1.0  2.0  2.0  3.0  3.0

# %% [markdown]
# 'dataset.describe().transpose()' untuk mendeskripsikan seluruh data bertipe interger seperti jumlah datanya, rata-rata nilai hingga max dan min nilai. Dalam kasus ini data yang berupa interger hanya ada pada atribut deg_malig saja.
