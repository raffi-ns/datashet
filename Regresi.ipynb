# %% [markdown]
# <a href="https://colab.research.google.com/github/raffi-ns/datashet/blob/main/Regresi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
dataset = pd.read_excel('01-31-03-2023 WARDAH.xlsx')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %%
dataset.keys()
# Out:
# Index(['Jumlah', 'Harga'], dtype='object')

# %%
dataset.shape
# Out:
# (167, 2)

# %%
dataku = pd.DataFrame(dataset)
dataku.head()
# Out:
#    Jumlah   Harga
# 0       1   59000
# 1       1   23000
# 2       4  112000
# 3       1   75000
# 4       1   66000

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
plt.scatter(dataku.Jumlah, dataku.Harga)
plt.xlabel("Biaya Produksi")
plt.ylabel("Nilai Penjualan")
plt.title("Grafik Barang Terjual vs Harga Penjualan")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
 plt.figure(figsize=(10,8))
 plt.scatter(x_train, y_train, color = 'blue')
 plt.plot(x_train, regressor.predict(x_train), color = 'red')
 plt.xlabel("Jumlah Juali")
 plt.ylabel("Harga Jual")
 plt.title("Grafik Barang Terjual vs Harga Penjualan (Training Set)")
 plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
 plt.figure(figsize=(10,8))
 plt.scatter(x_test, y_test, color = 'blue')
 plt.plot(x_test, regressor.predict(x_test), color = 'red')
 plt.xlabel("Jumlah Juali")
 plt.ylabel("Harga Jual")
 plt.title("Grafik Barang Terjual vs Harga Penjualan (Training Set)")
 plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
